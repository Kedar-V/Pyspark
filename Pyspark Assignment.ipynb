# %% [markdown]
# # Data Loading

# %%
# !pip install  kagglehub
# Out:
# Requirement already satisfied: kagglehub in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b2a64a5b-3214-4d8e-aab3-3b9492b861f0/lib/python3.12/site-packages (0.3.13)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in /databricks/python3/lib/python3.12/site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b2a64a5b-3214-4d8e-aab3-3b9492b861f0/lib/python3.12/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests->kagglehub) (2025.1.31)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import os
dbutils.fs.mkdirs("/Workspace/Users/kedarvaidya0504@gmail.com/kaggle")
os.environ["KAGGLEHUB_CACHE_DIR"] = "/Workspace/Users/kedarvaidya0504@gmail.com/kaggle"

import kagglehub

# Download latest version
path = kagglehub.dataset_download("khandelwalmanas/daily-commodity-prices-india")

print("Path to dataset files:", path)

# %%
# !cp -r /home/spark-32071c93-e691-42b5-97a4-9c/.cache/kagglehub/datasets/khandelwalmanas/daily-commodity-prices-india/versions/22 /Workspace/Users/kedarvaidya0504@gmail.com
# Out:
# cp: error writing '/Workspace/Users/kedarvaidya0504@gmail.com/22/csv/2024.csv': File too large
# cp: failed to close '/Workspace/Users/kedarvaidya0504@gmail.com/22/csv/2024.csv': File too large
# cp: error writing '/Workspace/Users/kedarvaidya0504@gmail.com/22/csv/2025.csv': File too large
# cp: failed to close '/Workspace/Users/kedarvaidya0504@gmail.com/22/csv/2025.csv': File too large

# %%
# %sql
CREATE VOLUME workspace.default.pyspark;

# %%
dbutils.fs.cp(
    "/Workspace/Users/kedarvaidya0504@gmail.com/22/parquet/",
    "dbfs:/Volumes/workspace/default/pyspark/",
    recurse=True
)
# Out:
# True

# %%
import pyspark.sql.functions as F

bad_files = []

for p in paths:
    try:
        df_test = spark.read.parquet(p)
        print("OK:", p)
    except Exception as e:
        print("BAD:", p)
        bad_files.append(p)
# Out:
# OK: dbfs:/Volumes/workspace/default/pyspark/_SUCCESS
# OK: dbfs:/Volumes/workspace/default/pyspark/_committed_5458989634332253454
# OK: dbfs:/Volumes/workspace/default/pyspark/_committed_7275890549864832928
# OK: dbfs:/Volumes/workspace/default/pyspark/_started_5458989634332253454
# OK: dbfs:/Volumes/workspace/default/pyspark/_started_7275890549864832928
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00000-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-645-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00001-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-649-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00002-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-650-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00003-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-651-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00004-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-652-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00005-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-653-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00006-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-654-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00007-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-646-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00008-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-655-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00009-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-656-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00010-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-657-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00011-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-658-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00012-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-659-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00013-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-660-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00014-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-647-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00015-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-661-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00016-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-662-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00017-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-648-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00018-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-663-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00019-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-664-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00020-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-665-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00021-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-666-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00022-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-667-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00023-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-668-1.c000.snappy.parquet
# OK: dbfs:/Volumes/workspace/default/pyspark/part-00024-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-669-1.c000.snappy.parquet

# %%
import pyspark.sql.functions as F

paths = [
    f.path for f in dbutils.fs.ls("dbfs:/Volumes/workspace/default/pyspark")
    if f.path.endswith(".parquet")
]

dfs = []
for p in paths:
    df_i = (
        spark.read.parquet(p)
        .withColumn("Min_Price", F.col("Min_Price").cast("double"))
        .withColumn("Modal_Price", F.col("Modal_Price").cast("double"))
        .withColumn("Max_Price", F.col("Max_Price").cast("double"))
    )
    dfs.append(df_i)

df_clean = dfs[0]
for d in dfs[1:]:
    df_clean = df_clean.unionByName(d)

display(df_clean.head(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th>District</th><th>Market</th><th>Commodity</th><th>Variety</th><th>Grade</th><th>Arrival_Date</th><th>Min_Price</th><th>Max_Price</th><th>Modal_Price</th><th>Commodity_Code</th></tr></thead><tbody><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Bengal Gram (Gram)(Whole)</td><td>Average (Whole)</td><td>FAQ</td><td>2001-01-10</td><td>1400.0</td><td>1400.0</td><td>1400.0</td><td>6</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Black Gram (Urd Beans)(Whole)</td><td>Black Gram (Whole)</td><td>FAQ</td><td>2001-01-10</td><td>1380.0</td><td>1380.0</td><td>1380.0</td><td>8</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Green Gram (Moong)(Whole)</td><td>Green (Whole)</td><td>FAQ</td><td>2001-01-10</td><td>1600.0</td><td>1900.0</td><td>1800.0</td><td>9</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Groundnut</td><td>Gejje</td><td>FAQ</td><td>2001-01-10</td><td>601.0</td><td>1181.0</td><td>1105.0</td><td>10</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Maize</td><td>Local</td><td>FAQ</td><td>2001-01-10</td><td>420.0</td><td>445.0</td><td>440.0</td><td>4</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Onion</td><td>Telagi</td><td>FAQ</td><td>2001-01-10</td><td>50.0</td><td>300.0</td><td>250.0</td><td>23</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Onion</td><td>Local</td><td>FAQ</td><td>2001-01-10</td><td>50.0</td><td>250.0</td><td>230.0</td><td>23</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Onion</td><td>Puna</td><td>FAQ</td><td>2001-01-10</td><td>150.0</td><td>350.0</td><td>280.0</td><td>23</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Potato</td><td>Potato</td><td>FAQ</td><td>2001-01-10</td><td>380.0</td><td>850.0</td><td>600.0</td><td>24</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Same/Savi</td><td>Same/Savi Local</td><td>FAQ</td><td>2001-01-10</td><td>771.0</td><td>771.0</td><td>771.0</td><td>122</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Sunflower</td><td>Sunflower</td><td>FAQ</td><td>2001-01-10</td><td>1409.0</td><td>1409.0</td><td>1409.0</td><td>14</td></tr><tr><td>Karnataka</td><td>Dharwad</td><td>Hubli (Amaragol)</td><td>Wheat</td><td>White</td><td>FAQ</td><td>2001-01-10</td><td>771.0</td><td>771.0</td><td>771.0</td><td>1</td></tr><tr><td>Maharashtra</td><td>Kolhapur</td><td>Kolhapur</td><td>Brinjal</td><td>Round</td><td>FAQ</td><td>2001-01-27</td><td>400.0</td><td>750.0</td><td>575.0</td><td>35</td></tr><tr><td>Maharashtra</td><td>Kolhapur</td><td>Kolhapur</td><td>Cauliflower</td><td>Other</td><td>FAQ</td><td>2001-01-27</td><td>90.0</td><td>225.0</td><td>150.0</td><td>34</td></tr><tr><td>Maharashtra</td><td>Kolhapur</td><td>Kolhapur</td><td>Coriander (Leaves)</td><td>Local</td><td>FAQ</td><td>2001-01-27</td><td>600.0</td><td>1000.0</td><td>800.0</td><td>43</td></tr><tr><td>Maharashtra</td><td>Kolhapur</td><td>Kolhapur</td><td>Grapes</td><td>Green</td><td>Medium</td><td>2001-01-27</td><td>1200.0</td><td>2500.0</td><td>1850.0</td><td>22</td></tr><tr><td>Maharashtra</td><td>Kolhapur</td><td>Kolhapur</td><td>Orange</td><td>Nagpuri</td><td>Medium</td><td>2001-01-27</td><td>800.0</td><td>1100.0</td><td>950.0</td><td>18</td></tr><tr><td>Maharashtra</td><td>Kolhapur</td><td>Kolhapur</td><td>
td><td>Other</td><td>FAQ</td><td>2025-11-05</td><td>7200.0</td><td>7500.0</td><td>7300.0</td><td>80</td></tr><tr><td>Kerala</td><td>Kozhikode (Calicut)</td><td>Vengeri (Kozhikode)</td><td>Ginger (Green)</td><td>Green Ginger</td><td>FAQ</td><td>2025-11-05</td><td>6500.0</td><td>6800.0</td><td>6800.0</td><td>103</td></tr><tr><td>Kerala</td><td>Kottayam</td><td>Ettumanoor</td><td>Bitter gourd</td><td>Other</td><td>FAQ</td><td>2025-11-05</td><td>5400.0</td><td>5800.0</td><td>5600.0</td><td>81</td></tr><tr><td>Kerala</td><td>Kollam</td><td>Chathanoor</td><td>Indian Beans (Seam)</td><td>Other</td><td>FAQ</td><td>2025-11-05</td><td>9800.0</td><td>10200.0</td><td>10000.0</td><td>299</td></tr><tr><td>Kerala</td><td>Palakad</td><td>Koduvayoor</td><td>Mango</td><td>Other</td><td>Medium</td><td>2025-11-05</td><td>5200 ...
# root
#  |-- State: string (nullable = true)
#  |-- District: string (nullable = true)
#  |-- Market: string (nullable = true)
#  |-- Commodity: string (nullable = true)
#  |-- Variety: string (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Arrival_Date: string (nullable = true)
#  |-- Min_Price: double (nullable = true)
#  |-- Max_Price: double (nullable = true)
#  |-- Modal_Price: double (nullable = true)
#  |-- Commodity_Code: long (nullable = true)

# %% [markdown]
# # Data Preprocessing

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# ===============================
# State → Region lookup table
# ===============================
region_lookup = spark.createDataFrame([
    ("Punjab", "North"),
    ("Haryana", "North"),
    ("Uttar Pradesh", "North"),
    ("Delhi", "North"),
    ("Himachal Pradesh", "North"),
    ("Jammu and Kashmir", "North"),
    ("Maharashtra", "West"),
    ("Gujarat", "West"),
    ("Rajasthan", "West"),
    ("Goa", "West"),
    ("Karnataka", "South"),
    ("Tamil Nadu", "South"),
    ("Kerala", "South"),
    ("Andhra Pradesh", "South"),
    ("Telangana", "South"),
    ("Bihar", "East"),
    ("Odisha", "East"),
    ("Jharkhand", "East"),
    ("West Bengal", "East"),
    ("Assam", "North-East"),
    ("Nagaland", "North-East"),
    ("Manipur", "North-East"),
    ("Tripura", "North-East"),
    ("Sikkim", "North-East"),
], ["State", "Region"])


# ===============================
# 2. Main preprocessing pipeline
# ===============================
df_preprocessed = (
    df_clean

    # ----- FILTERS -----
    .filter(F.col("Arrival_Date") >= "2016-01-01")
    .filter(
        (F.col("Min_Price").isNotNull()) &
        (F.col("Max_Price").isNotNull()) &
        (F.col("Modal_Price").isNotNull()) &
        (F.col("Max_Price") >= F.col("Min_Price"))
    )

    # ----- COLUMN TRANSFORMATIONS -----
    .withColumn("Arrival_Date", F.to_date("Arrival_Date", "yyyy-MM-dd"))
    .withColumn("Year", F.year("Arrival_Date"))
    .withColumn("Month", F.month("Arrival_Date"))
    .withColumn("Quarter", F.quarter("Arrival_Date"))
    .withColumn("Price_Spread", F.col("Max_Price") - F.col("Min_Price"))
    .withColumn("Modal_Price_Kg", F.col("Modal_Price") / 100)
    .withColumn("Max_Min_Ratio", F.try_divide(F.col("Max_Price"), F.col("Min_Price")))
    .withColumn("State_Upper", F.upper("State"))
    .withColumn("District_Upper", F.upper("District"))

    # ----- STATE → REGION JOIN -----
    .join(F.broadcast(region_lookup), "State", "left")
)

# %% [markdown]
# # A) Market-level daily summary

# %%
df_market_agg = (
    df_preprocessed
        .groupBy("State", "Region", "District", "Market", "Arrival_Date")
        .agg(
            F.count("*").alias("Num_Records"),
            F.avg("Modal_Price").alias("Avg_Modal_Price"),
            F.avg("Price_Spread").alias("Avg_Spread"),
            F.max("Max_Price").alias("Daily_Max_Price")
        )
)
display(df_market_agg.head(1000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th
# %% [markdown]
# #1) Top 3 Cheapest Markets per Commodity ( Monthly Rolling Trend )

# %%
query1 = spark.sql('''
WITH rolling AS (
    SELECT
        Commodity,
        Market,
        date_format(Arrival_Date, 'yyyy-MM') AS YearMonth,
        Modal_Price,
        Price_Spread,
        AVG(Modal_Price) OVER (
            PARTITION BY Commodity
            ORDER BY Arrival_Date
            ROWS BETWEEN 14 PRECEDING AND CURRENT ROW
        ) AS Rolling14
    FROM preprocessed_data
    WHERE Arrival_Date >= '2018-01-01'
),

monthly_agg AS (
    SELECT
        Commodity,
        YearMonth,
        Market,
        AVG(Rolling14) AS Avg_Roll14,
        AVG(Price_Spread) AS Avg_Spread,
        COUNT(*) AS Records
    FROM rolling
    GROUP BY Commodity, YearMonth, Market
),

ranked AS (
    SELECT
        *,
        RANK() OVER (
            PARTITION BY Commodity, YearMonth
            ORDER BY Avg_Roll14 ASC
        ) AS Rank
    FROM monthly_agg
)

SELECT *
FROM ranked
WHERE Rank <= 3
ORDER BY Commodity, YearMonth, Rank;
''')
display(query1.head(1000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Commodity</th><th>YearMonth</th><th>Market</th><th>Avg_Roll14</th><th>Avg_Spread</th><th>Records</th><th>Rank</th></tr></thead><tbody><tr><td>Absinthe</td><td>2024-08</td><td>Neemuch</td><td>1968.75</td><td>0.0</td><td>2</td><td>1</td></tr><tr><td>Absinthe</td><td>2024-09</td><td>Khandwa</td><td>1896.2</td><td>5.0</td><td>1</td><td>1</td></tr><tr><td>Absinthe</td><td>2024-09</td><td>Neemuch</td><td>2046.5968614718613</td><td>15.25</td><td>4</td><td>2</td></tr><tr><td>Absinthe</td><td>2024-09</td><td>Umariya</td><td>2081.4263888888886</td><td>0.0</td><td>4</td><td>3</td></tr><tr><td>Absinthe</td><td>2024-10</td><td>Umariya</td><td>2204.8416666666667</td><td>0.0</td><td>2</td><td>1</td></tr><tr><td>Absinthe</td><td>2024-10</td><td>Neemuch</td><td>2312.7524542124543</td><td>51.8</td><td>5</td><td>2</td></tr><tr><td>Absinthe</td><td>2024-11</td><td>Neemuch</td><td>3630.095238095238</td><td>910.2857142857143</td><td>14</td><td>1</td></tr><tr><td>Absinthe</td><td>2024-12</td><td>Umariya</td><td>4889.133333333333</td><td>0.0</td><td>1</td><td>1</td></tr><tr><td>Absinthe</td><td>2024-12</td><td>Neemuch</td><td>5028.477777777778</td><td>385.1666666666667</td><td>12</td><td>2</td></tr><tr><td>Absinthe</td><td>2025-01</td><td>Umariya</td><td>4366.007407407407</td><td>22.22222222222222</td><td>9</td><td>1</td></tr><tr><td>Absinthe</td><td>2025-01</td><td>Neemuch</td><td>4471.280000000001</td><td>0.0</td><td>5</td><td>2</td></tr><tr><td>Absinthe</td><td>2025-02</td><td>Neemuch</td><td>4964.733333333334</td><td>160.0</td><td>8</td><td>1</td></tr><tr><td>Absinthe</td><td>2025-03</td><td>Neemuch</td><td>6485.466666666666</td><td>0.0</td><td>1</td><td>1</td></tr><tr><td>Absinthe</td><td>2025-03</td><td>Manasa</td><td>6748.8</td><td>150.0</td><td>1</td><td>2</td></tr><tr><td>Absinthe</td><td>2025-06</td><td>Neemuch</td><td>7018.8</td><td>550.0</td><td>1</td><td>1</td></tr><tr><td>Absinthe</td><td>2025-07</td><td>Neemuch</td><td>7262.133333333333</td><td>0.0</td><td>2</td><td>1</td></tr><tr><td>Absinthe</td><td>2025-09</td><td>Neemuch</td><td>8348.644444444444</td><td>635.1666666666666</td><td>6</td><td>1</td></tr><tr><td>Absinthe</td><td>2025-10</td><td>Neemuch</td><td>8988.866666666667</td><td>1156.6666666666667</td><td>3</td><td>1</td></tr><tr><td>Ajwan</td><td>2018-01</td><td>Sailana</td><td>6561.666666666667</td><td>434.0</td><td>1</td><td>1</td></tr><tr><td>Ajwan</td><td>2018-01</td><td>Ashoknagar</td><td>6901.433333333333</td><td>145.5</td><td>2</td><td>2</td></tr><tr><td>Ajwan</td><td>2018-01</td><td>Jodhpur (Grain)</td><td>7538.233333333334</td><td>550.0</td><td>2</td><td>3</td></tr><tr><td>Ajwan</td><td>2018-02</td><td>Bhopal</td><td>6950.133333333333</td><td>726.0</td><td>1</td><td>1</td></tr><tr><td>Ajwan</td><td>2018-02</td><td>Vav</td><td>7293.666666666667</td><td>3840.0</td><td>1</td><td>2</td></tr><tr><td>Ajwan</td><td>2018-02</td><td>Sami</td><td>7313.633333333334</td><td>770.8333333333334</td><td>6</td><td>3</td></tr><tr><td>Ajwan</td><td>2018-03</td><td>Lasur Station</td><td>6691.733333333334</td><td>500.0</td><td>1</td><td>1</td></tr><tr><td>Ajwan</td><td>2018-03</td><td>Bhilwara</td><td>6927.948717948717</td><td>1161.5384615384614</td><td>13</td><td>2</td></tr><tr><td>Ajwan</td><td>2018-03</td><td>Shegaon</td><td>6942.046666666666</td><td>1691.5</td><td>20</td><td>3</td></tr><tr><td>Ajwan</td><td>2018-04</td><td>Lasur Station</td><td>6317.666666666667</td><td>1999.0</td><td>1</td><td>1</td></tr><tr><td>Ajwan</td><td>2018-04</td><td>Nadiad</td><td>6478.4</td><td>1500.0</td><td>1</td><td>2</td></tr><tr><td>Ajwan</td><td>2018-04</td><td>Sami</td><td>6563.944444444444</td><td>1312.5</td><td>12</td><td>3</td></tr><tr><td>Ajwan</td><td>2018-05</td><td>Bhilwara</td><td>6591.812820512821</td><td>1030.7692307692307</td><td>13</td><td>1</td></tr><tr><td>Ajwan</td><td>2018-05</td><td>Shegaon</td><td>6592.723333333332</ ...

# %%
query2 = spark.sql('''
WITH stats AS (
    SELECT
        State,
        Market,
        Arrival_Date,
        date_format(Arrival_Date, 'yyyy-MM') AS YearMonth,
        Modal_Price,

        -- 60-day moving average
        AVG(Modal_Price) OVER (
            PARTITION BY Market
            ORDER BY Arrival_Date
            ROWS BETWEEN 60 PRECEDING AND CURRENT ROW
        ) AS MA60,

        -- 60-day moving standard deviation
        STDDEV(Modal_Price) OVER (
            PARTITION BY Market
            ORDER BY Arrival_Date
            ROWS BETWEEN 60 PRECEDING AND CURRENT ROW
        ) AS STD60
    FROM preprocessed_data
),

zscores AS (
    SELECT
        *,
        TRY_DIVIDE(Modal_Price - MA60, STD60) AS ZScore60
    FROM stats
)

SELECT
    State,
    Market,
    YearMonth,
    AVG(ZScore60) AS Avg_ZScore,
    AVG(STD60) AS Avg_STD60,
    MAX(STD60) AS Peak_STD60,
    COUNT(*) AS Num_Records
FROM zscores
GROUP BY State, Market, YearMonth
ORDER BY Market, YearMonth;
'''
)

display(query2.head(1000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
)

df_bad_result = df_bad.orderBy("Commodity", "Year")
df_bad_result.count()
# Out:
# 642

# %%
# Optimised
df_opt = (
    df_clean
        .withColumn("Year", F.year("Arrival_Date"))
        .filter("Year >= 2024")                            # early filter
        .select("Commodity", "Year", "Modal_Price")        # prune unnecessary columns
        .repartition("Year")                               # cluster same Year values
        .groupBy("Commodity", "Year")
        .agg(F.avg("Modal_Price").alias("AvgPrice"))
)

df_opt_result = df_opt.orderBy("Commodity", "Year")
df_opt_result.count()
# Out:
# 642

# %%
df_opt_result.write.mode("overwrite").format("delta").saveAsTable("default.Yearly")

# %% [markdown]
# ### Example 2: 30-Day Rolling Average Price per Commodity

# %%
# Unoptimised

from pyspark.sql import functions as F
from pyspark.sql.window import Window

# A lookup table of commodity codes (small)
lookup = df_clean.select("Commodity_Code").distinct()

df_bad_complex = (
    df_clean
        .join(lookup, "Commodity_Code")                        # huge join early
        .withColumn("Year", F.year("Arrival_Date"))             # compute Year early
        .repartition(2500)                                      # random massive shuffle
        .withColumn(
            "RollingAvg30",
            F.avg("Modal_Price").over(
                Window.partitionBy("Commodity")
                      .orderBy("Arrival_Date")
                      .rowsBetween(-30, 0)
            )
        )                                                       # window on full data
        .filter("Year >= 2024")                                 # filtering too late
        .select("Commodity", "Market", "Arrival_Date", "RollingAvg30")
)

df_bad_complex_result = df_bad_complex.orderBy("Commodity", "Arrival_Date")
display(df_bad_complex_result.head(1000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Commodity</th><th>Market</th><th>Arrival_Date</th><th>RollingAvg30</th></tr></thead><tbody><tr><td>Absinthe</td><td>Neemuch</td><td>2024-08-20</td><td>2125.0</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-08-22</td><td>1812.5</td></tr><tr><td>Absinthe</td><td>Umariya</td><td>2024-09-01</td><td>2008.3333333333333</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-09-04</td><td>1984.0</td></tr><tr><td>Absinthe</td><td>Khandwa</td><td>2024-09-06</td><td>1896.2</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-09-09</td><td>2062.1666666666665</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-09-11</td><td>2024.857142857143</td></tr><tr><td>Absinthe</td><td>Umariya</td><td>2024-09-13</td><td>2071.75</td></tr><tr><td>Absinthe</td><td>Umariya</td><td>2024-09-20</td><td>2108.222222222222</td></tr><tr><td>Absinthe</td><td>Umariya</td><td>2024-09-22</td><td>2137.4</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-09-27</td><td>2115.3636363636365</td></tr><tr><td>Absinthe</td><td>Umariya</td><td>2024-10-10</td><td>2139.0833333333335</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-10-15</td><td>2214.5384615384614</td></tr><tr><td>Absinthe</td><td>Umariya</td><td>2024-10-16</td><td>2270.6</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-10-16</td><td>2261.3571428571427</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-10-21</td><td>2319.3125</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-10-23</td><td>2288.764705882353</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-10-24</td><td>2337.5</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-06</td><td>2469.7368421052633</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-11</td><td>2572.3</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-12</td><td>2640.285714285714</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-13</td><td>2721.5454545454545</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-14</td><td>2795.8260869565215</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-16</td><td>2860.5833333333335</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-18</td><td>2922.16</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-19</td><td>2994.8846153846152</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-20</td><td>3061.814814814815</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-21</td><td>3202.464285714286</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-22</td><td>3260.310344827586</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-25</td><td>3339.3</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-26</td><td>3406.8064516129034</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-11-27</td><td>3557.967741935484</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12-02</td><td>3678.967741935484</td></tr><tr><td>Absinthe</td><td>Umariya</td><td>2024-12-03</td><td>3769.2580645161293</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12-03</td><td>3772.8387096774195</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12-05</td><td>3888.451612903226</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12-06</td><td>3969.032258064516</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12-07</td><td>4067.3870967741937</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12-09</td><td>4125.4838709677415</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12-11</td><td>4217.5161290322585</td></tr><tr><td>Absinthe</td><td>Neemuch</td><td>2024-12
td></tr><tr><td>451</td><td>Absinthe</td><td>Neemuch</td><td>2024-11-27</td><td>6811.0</td><td>3557.967741935484</td></tr><tr><td>451</td><td>Absinthe</td><td>Neemuch</td><td>2024-12-02</td><td>5251.0</td><td>3678.967741935484</td></tr><tr><td>451</td><td>Absinthe</td><td>Umariya</td><td>2024-12-03</td><td>1800.0</td><td>3769.25806451 ...

# %%
# %sql
DROP VOLUME IF EXISTS workspace.default.RollingAvg30;
CREATE VOLUME workspace.default.RollingAvg30;

# %%
df_opt_complex_result.write.mode("overwrite").parquet("/Volumes/workspace/default/RollingAvg30")

# %% [markdown]
# # Performance Analysis

# %%
print("UNOPTIMIZED PLAN:")
df_bad.explain("formatted")

print("UNOPTIMIZED COUNT:")
bad_count = df_bad.count()
# Out:
# UNOPTIMIZED PLAN:
# == Physical Plan ==
# AdaptiveSparkPlan (63)
# +- == Initial Plan ==
#    ColumnarToRow (62)
#    +- PhotonResultStage (61)
#       +- PhotonGroupingAgg (60)
#          +- PhotonShuffleExchangeSource (59)
#             +- PhotonShuffleMapStage (58)
#                +- PhotonShuffleExchangeSink (57)
#                   +- PhotonGroupingAgg (56)
#                      +- PhotonShuffleExchangeSource (55)
#                         +- PhotonShuffleMapStage (54)
#                            +- PhotonShuffleExchangeSink (53)
#                               +- PhotonSort (52)
#                                  +- PhotonUnion (51)
#                                     :- PhotonProject (2)
#                                     :  +- PhotonScan parquet  (1)
#                                     :- PhotonProject (4)
#                                     :  +- PhotonScan parquet  (3)
#                                     :- PhotonProject (6)
#                                     :  +- PhotonScan parquet  (5)
#                                     :- PhotonProject (8)
#                                     :  +- PhotonScan parquet  (7)
#                                     :- PhotonProject (10)
#                                     :  +- PhotonScan parquet  (9)
#                                     :- PhotonProject (12)
#                                     :  +- PhotonScan parquet  (11)
#                                     :- PhotonProject (14)
#                                     :  +- PhotonScan parquet  (13)
#                                     :- PhotonProject (16)
#                                     :  +- PhotonScan parquet  (15)
#                                     :- PhotonProject (18)
#                                     :  +- PhotonScan parquet  (17)
#                                     :- PhotonProject (20)
#                                     :  +- PhotonScan parquet  (19)
#                                     :- PhotonProject (22)
#                                     :  +- PhotonScan parquet  (21)
#                                     :- PhotonProject (24)
#                                     :  +- PhotonScan parquet  (23)
#                                     :- PhotonProject (26)
#                                     :  +- PhotonScan parquet  (25)
#                                     :- PhotonProject (28)
#                                     :  +- PhotonScan parquet  (27)
#                                     :- PhotonProject (30)
#                                     :  +- PhotonScan parquet  (29)
#                                     :- PhotonProject (32)
#                                     :  +- PhotonScan parquet  (31)
#                                     :- PhotonProject (34)
#                                     :  +- PhotonScan parquet  (33)
#                                     :- PhotonProject (36)
#                                     :  +- PhotonScan parquet  (35)
#                                     :- PhotonProject (38)
#                                     :  +- PhotonScan parquet  (37)
#                                     :- PhotonProject (40)
#                                     :  +- PhotonScan parquet  (39)
#                                     :- PhotonProject (42)
#                                     :  +- PhotonScan parquet  (41)
#                                     :- PhotonProject (44)
#                                     :  +- PhotonScan parquet  (43)
#                                     :- PhotonProject (46)
#                                     :  +- PhotonScan parquet  (45)
#                                     :- PhotonProject (48)
#                                     :  +- PhotonScan parquet  (47)
#                                     +- PhotonProject (50)
#                                        +- PhotonScan parquet  (49)
#
#
# (1) PhotonScan parquet
# Output [3]: [Commodity#12243, Arrival_Date#12246, Modal_Price#12249]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00000-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-645-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12246), (year(cast(Arrival_Date#12246 as date)) >= 2024)]
#
# (2) PhotonProject
# Input [3]: [Commodity#12243, Arrival_Date#12246, Modal_Price#12249]
# Arguments: [Commodity#12243, Modal_Price#12249 AS Modal_Price#12749, year(cast(Arrival_Date#12246 as date)) AS Year#17497]
#
# (3) PhotonScan parquet
# Output [3]: [Commodity#12261, Arrival_Date#12264, Modal_Price#12267]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00001-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-649-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12264), (year(cast(Arrival_Date#12264 as date)) >= 2024)]
#
# (4) PhotonProject
# Input [3]: [Commodity#12261, Arrival_Date#12264, Modal_Price#12267]
# Arguments: [Commodity#12261, Modal_Price#12267, year(cast(Arrival_Date#12264 as date)) AS Year#19893]
#
# (5) PhotonScan parquet
# Output [3]: [Commodity#12279, Arrival_Date#12282, Modal_Price#12285]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00002-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-650-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12282), (year(cast(Arrival_Date#12282 as date)) >= 2024)]
#
# (6) PhotonProject
# Input [3]: [Commodity#12279, Arrival_Date#12282, Modal_Price#12285]
# Arguments: [Commodity#12279, Modal_Price#12285, year(cast(Arrival_Date#12282 as date)) AS Year#19894]
#
# (7) PhotonScan parquet
# Output [3]: [Commodity#12297, Arrival_Date#12300, Modal_Price#12303]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00003-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-651-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12300), (year(cast(Arrival_Date#12300 as date)) >= 2024)]
#
# (8) PhotonProject
# Input [3]: [Commodity#12297, Arrival_Date#12300, Modal_Price#12303]
# Arguments: [Commodity#12297, Modal_Price#12303, year(cast(Arrival_Date#12300 as date)) AS Year#19895]
#
# (9) PhotonScan parquet
# Output [3]: [Commodity#12315, Arrival_Date#12318, Modal_Price#12321]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00004-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-652-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12318), (year(cast(Arrival_Date#12318 as date)) >= 2024)]
#
# (10) PhotonProject
# Input [3]: [Commodity#12315, Arrival_Date#12318, Modal_Price#12321]
# Arguments: [Commodity#12315, Modal_Price#12321, year(cast(Arrival_Date#12318 as date)) AS Year#19896]
#
# (11) PhotonScan parquet
# Output [3]: [Commodity#12333, Arrival_Date#12336, Modal_Price#12339]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00005-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-653-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12336), (year(cast(Arrival_Date#12336 as date)) >= 2024)]
#
# (12) PhotonProject
# Input [3]: [Commodity#12333, Arrival_Date#12336, Modal_Price#12339]
# Arguments: [Commodity#12333, Modal_Price#12339, year(cast(Arrival_Date#12336 as date)) AS Year#19897]
#
# (13) PhotonScan parquet
# Output [3]: [Commodity#12351, Arrival_Date#12354, Modal_Price#12357]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00006-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-654-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12354), (year(cast(Arrival_Date#12354 as date)) >= 2024)]
#
# (14) PhotonProject
# Input [3]: [Commodity#12351, Arrival_Date#12354, Modal_Price#12357]
# Arguments: [Commodity#12351, Modal_Price#12357, year(cast(Arrival_Date#12354 as date)) AS Year#19898]
#
# (15) PhotonScan parquet
# Output [3]: [Commodity#12369, Arrival_Date#12372, Modal_Price#12375]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00007-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-646-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12372), (year(cast(Arrival_Date#12372 as date)) >= 2024)]
#
# (16) PhotonProject
# Input [3]: [Commodity#12369, Arrival_Date#12372, Modal_Price#12375]
# Arguments: [Commodity#12369, Modal_Price#12375, year(cast(Arrival_Date#12372 as date)) AS Year#19899]
#
# (17) PhotonScan parquet
# Output [3]: [Commodity#12387, Arrival_Date#12390, Modal_Price#12393]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00008-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-655-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12390), (year(cast(Arrival_Date#12390 as date)) >= 2024)]
#
# (18) PhotonProject
# Input [3]: [Commodity#12387, Arrival_Date#12390, Modal_Price#12393]
# Arguments: [Commodity#12387, Modal_Price#12393, year(cast(Arrival_Date#12390 as date)) AS Year#19900]
#
# (19) PhotonScan parquet
# Output [3]: [Commodity#12405, Arrival_Date#12408, Modal_Price#12411]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00009-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-656-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12408), (year(cast(Arrival_Date#12408 as date)) >= 2024)]
#
# (20) PhotonProject
# Input [3]: [Commodity#12405, Arrival_Date#12408, Modal_Price#12411]
# Arguments: [Commodity#12405, Modal_Price#12411, year(cast(Arrival_Date#12408 as date)) AS Year#19901]
#
# (21) PhotonScan parquet
# Output [3]: [Commodity#12423, Arrival_Date#12426, Modal_Price#12429]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00010-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-657-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12426), (year(cast(Arrival_Date#12426 as date)) >= 2024)]
#
# (22) PhotonProject
# Input [3]: [Commodity#12423, Arrival_Date#12426, Modal_Price#12429]
# Arguments: [Commodity#12423, Modal_Price#12429, year(cast(Arrival_Date#12426 as date)) AS Year#19902]
#
# (23) PhotonScan parquet
# Output [3]: [Commodity#12441, Arrival_Date#12444, Modal_Price#12447]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00011-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-658-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12444), (year(cast(Arrival_Date#12444 as date)) >= 2024)]
#
# (24) PhotonProject
# Input [3]: [Commodity#12441, Arrival_Date#12444, Modal_Price#12447]
# Arguments: [Commodity#12441, Modal_Price#12447, year(cast(Arrival_Date#12444 as date)) AS Year#19903]
#
# (25) PhotonScan parquet
# Output [3]: [Commodity#12459, Arrival_Date#12462, Modal_Price#12465]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00012-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-659-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12462), (year(cast(Arrival_Date#12462 as date)) >= 2024)]
#
# (26) PhotonProject
# Input [3]: [Commodity#12459, Arrival_Date#12462, Modal_Price#12465]
# Arguments: [Commodity#12459, Modal_Price#12465, year(cast(Arrival_Date#12462 as date)) AS Year#19904]
#
# (27) PhotonScan parquet
# Output [3]: [Commodity#12477, Arrival_Date#12480, Modal_Price#12483]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00013-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-660-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12480), (year(cast(Arrival_Date#12480 as date)) >= 2024)]
#
# (28) PhotonProject
# Input [3]: [Commodity#12477, Arrival_Date#12480, Modal_Price#12483]
# Arguments: [Commodity#12477, Modal_Price#12483, year(cast(Arrival_Date#12480 as date)) AS Year#19905]
#
# (29) PhotonScan parquet
# Output [3]: [Commodity#12495, Arrival_Date#12498, Modal_Price#12501]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00014-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-647-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12498), (year(cast(Arrival_Date#12498 as date)) >= 2024)]
#
# (30) PhotonProject
# Input [3]: [Commodity#12495, Arrival_Date#12498, Modal_Price#12501]
# Arguments: [Commodity#12495, Modal_Price#12501, year(cast(Arrival_Date#12498 as date)) AS Year#19906]
#
# (31) PhotonScan parquet
# Output [3]: [Commodity#12513, Arrival_Date#12516, Modal_Price#12519]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00015-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-661-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12516), (year(cast(Arrival_Date#12516 as date)) >= 2024)]
#
# (32) PhotonProject
# Input [3]: [Commodity#12513, Arrival_Date#12516, Modal_Price#12519]
# Arguments: [Commodity#12513, Modal_Price#12519, year(cast(Arrival_Date#12516 as date)) AS Year#19907]
#
# (33) PhotonScan parquet
# Output [3]: [Commodity#12531, Arrival_Date#12534, Modal_Price#12537]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00016-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-662-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12534), (year(cast(Arrival_Date#12534 as date)) >= 2024)]
#
# (34) PhotonProject
# Input [3]: [Commodity#12531, Arrival_Date#12534, Modal_Price#12537]
# Arguments: [Commodity#12531, Modal_Price#12537, year(cast(Arrival_Date#12534 as date)) AS Year#19908]
#
# (35) PhotonScan parquet
# Output [3]: [Commodity#12549, Arrival_Date#12552, Modal_Price#12555]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00017-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-648-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12552), (year(cast(Arrival_Date#12552 as date)) >= 2024)]
#
# (36) PhotonProject
# Input [3]: [Commodity#12549, Arrival_Date#12552, Modal_Price#12555]
# Arguments: [Commodity#12549, Modal_Price#12555, year(cast(Arrival_Date#12552 as date)) AS Year#19909]
#
# (37) PhotonScan parquet
# Output [3]: [Commodity#12567, Arrival_Date#12570, Modal_Price#12573]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00018-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-663-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12570), (year(cast(Arrival_Date#12570 as date)) >= 2024)]
#
# (38) PhotonProject
# Input [3]: [Commodity#12567, Arrival_Date#12570, Modal_Price#12573]
# Arguments: [Commodity#12567, Modal_Price#12573, year(cast(Arrival_Date#12570 as date)) AS Year#19910]
#
# (39) PhotonScan parquet
# Output [3]: [Commodity#12585, Arrival_Date#12588, Modal_Price#12591]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00019-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-664-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12588), (year(cast(Arrival_Date#12588 as date)) >= 2024)]
#
# (40) PhotonProject
# Input [3]: [Commodity#12585, Arrival_Date#12588, Modal_Price#12591]
# Arguments: [Commodity#12585, Modal_Price#12591, year(cast(Arrival_Date#12588 as date)) AS Year#19911]
#
# (41) PhotonScan parquet
# Output [3]: [Commodity#12603, Arrival_Date#12606, Modal_Price#12609]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00020-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-665-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12606), (year(cast(Arrival_Date#12606 as date)) >= 2024)]
#
# (42) PhotonProject
# Input [3]: [Commodity#12603, Arrival_Date#12606, Modal_Price#12609]
# Arguments: [Commodity#12603, Modal_Price#12609, year(cast(Arrival_Date#12606 as date)) AS Year#19912]
#
# (43) PhotonScan parquet
# Output [3]: [Commodity#12621, Arrival_Date#12624, Modal_Price#12627]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00021-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-666-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12624), (year(cast(Arrival_Date#12624 as date)) >= 2024)]
#
# (44) PhotonProject
# Input [3]: [Commodity#12621, Arrival_Date#12624, Modal_Price#12627]
# Arguments: [Commodity#12621, Modal_Price#12627, year(cast(Arrival_Date#12624 as date)) AS Year#19913]
#
# (45) PhotonScan parquet
# Output [3]: [Commodity#12639, Arrival_Date#12642, Modal_Price#12645]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00022-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-667-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12642), (year(cast(Arrival_Date#12642 as date)) >= 2024)]
#
# (46) PhotonProject
# Input [3]: [Commodity#12639, Arrival_Date#12642, Modal_Price#12645]
# Arguments: [Commodity#12639, Modal_Price#12645, year(cast(Arrival_Date#12642 as date)) AS Year#19914]
#
# (47) PhotonScan parquet
# Output [3]: [Commodity#12657, Arrival_Date#12660, Modal_Price#12663]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00023-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-668-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12660), (year(cast(Arrival_Date#12660 as date)) >= 2024)]
#
# (48) PhotonProject
# Input [3]: [Commodity#12657, Arrival_Date#12660, Modal_Price#12663]
# Arguments: [Commodity#12657, Modal_Price#12663, year(cast(Arrival_Date#12660 as date)) AS Year#19915]
#
# (49) PhotonScan parquet
# Output [3]: [Commodity#12675, Arrival_Date#12678, Modal_Price#12681]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00024-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-669-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12678), (year(cast(Arrival_Date#12678 as date)) >= 2024)]
#
# (50) PhotonProject
# Input [3]: [Commodity#12675, Arrival_Date#12678, Modal_Price#12681]
# Arguments: [Commodity#12675, Modal_Price#12681, year(cast(Arrival_Date#12678 as date)) AS Year#19916]
#
# (51) PhotonUnion
# Arguments: Generic
#
# (52) PhotonSort
# Input [3]: [Commodity#12243, Modal_Price#12749, Year#17497]
# Arguments: [Commodity#12243 ASC NULLS FIRST, Modal_Price#12749 ASC NULLS FIRST, Year#17497 ASC NULLS FIRST]
#
# (53) PhotonShuffleExchangeSink
# Input [3]: [Commodity#12243, Modal_Price#12749, Year#17497]
# Arguments: RoundRobinPartitioning(2000)
#
# (54) PhotonShuffleMapStage
# Input [3]: [Commodity#12243, Modal_Price#12749, Year#17497]
# Arguments: REPARTITION_BY_NUM, [id=#36130]
#
# (55) PhotonShuffleExchangeSource
# Input [3]: [Commodity#12243, Modal_Price#12749, Year#17497]
#
# (56) PhotonGroupingAgg
# Input [3]: [Commodity#12243, Modal_Price#12749, Year#17497]
# Arguments: [Commodity#12243, Year#17497], [partial_avg(Modal_Price#12749) AS (sum#19919, count#19920L)], [sum#19917, count#19918L], [Commodity#12243, Year#17497, sum#19919, count#19920L], false
#
# (57) PhotonShuffleExchangeSink
# Input [4]: [Commodity#12243, Year#17497, sum#19919, count#19920L]
# Arguments: hashpartitioning(Commodity#12243, Year#17497, 16)
#
# (58) PhotonShuffleMapStage
# Input [4]: [Commodity#12243, Year#17497, sum#19919, count#19920L]
# Arguments: ENSURE_REQUIREMENTS, [id=#36136]
#
# (59) PhotonShuffleExchangeSource
# Input [4]: [Commodity#12243, Year#17497, sum#19919, count#19920L]
#
# (60) PhotonGroupingAgg
# Input [4]: [Commodity#12243, Year#17497, sum#19919, count#19920L]
# Arguments: [Commodity#12243, Year#17497], [finalmerge_avg(merge sum#19919, count#19920L) AS avg(Modal_Price)#19892], [avg(Modal_Price)#19892], [Commodity#12243, Year#17497, avg(Modal_Price)#19892 AS AvgPrice#17498], true
#
# (61) PhotonResultStage
# Input [3]: [Commodity#12243, Year#17497, AvgPrice#17498]
#
# (62) ColumnarToRow
# Input [3]: [Commodity#12243, Year#17497, AvgPrice#17498]
#
# (63) AdaptiveSparkPlan
# Output [3]: [Commodity#12243, Year#17497, AvgPrice#17498]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# UNOPTIMIZED COUNT:

# %%
print("OPTIMIZED PLAN:")
df_opt.explain("formatted")

print("OPTIMIZED COUNT:")
opt_count = df_opt.count()
# Out:
# OPTIMIZED PLAN:
# == Physical Plan ==
# AdaptiveSparkPlan (58)
# +- == Initial Plan ==
#    ColumnarToRow (57)
#    +- PhotonResultStage (56)
#       +- PhotonGroupingAgg (55)
#          +- PhotonShuffleExchangeSource (54)
#             +- PhotonShuffleMapStage (53)
#                +- PhotonShuffleExchangeSink (52)
#                   +- PhotonUnion (51)
#                      :- PhotonProject (2)
#                      :  +- PhotonScan parquet  (1)
#                      :- PhotonProject (4)
#                      :  +- PhotonScan parquet  (3)
#                      :- PhotonProject (6)
#                      :  +- PhotonScan parquet  (5)
#                      :- PhotonProject (8)
#                      :  +- PhotonScan parquet  (7)
#                      :- PhotonProject (10)
#                      :  +- PhotonScan parquet  (9)
#                      :- PhotonProject (12)
#                      :  +- PhotonScan parquet  (11)
#                      :- PhotonProject (14)
#                      :  +- PhotonScan parquet  (13)
#                      :- PhotonProject (16)
#                      :  +- PhotonScan parquet  (15)
#                      :- PhotonProject (18)
#                      :  +- PhotonScan parquet  (17)
#                      :- PhotonProject (20)
#                      :  +- PhotonScan parquet  (19)
#                      :- PhotonProject (22)
#                      :  +- PhotonScan parquet  (21)
#                      :- PhotonProject (24)
#                      :  +- PhotonScan parquet  (23)
#                      :- PhotonProject (26)
#                      :  +- PhotonScan parquet  (25)
#                      :- PhotonProject (28)
#                      :  +- PhotonScan parquet  (27)
#                      :- PhotonProject (30)
#                      :  +- PhotonScan parquet  (29)
#                      :- PhotonProject (32)
#                      :  +- PhotonScan parquet  (31)
#                      :- PhotonProject (34)
#                      :  +- PhotonScan parquet  (33)
#                      :- PhotonProject (36)
#                      :  +- PhotonScan parquet  (35)
#                      :- PhotonProject (38)
#                      :  +- PhotonScan parquet  (37)
#                      :- PhotonProject (40)
#                      :  +- PhotonScan parquet  (39)
#                      :- PhotonProject (42)
#                      :  +- PhotonScan parquet  (41)
#                      :- PhotonProject (44)
#                      :  +- PhotonScan parquet  (43)
#                      :- PhotonProject (46)
#                      :  +- PhotonScan parquet  (45)
#                      :- PhotonProject (48)
#                      :  +- PhotonScan parquet  (47)
#                      +- PhotonProject (50)
#                         +- PhotonScan parquet  (49)
#
#
# (1) PhotonScan parquet
# Output [3]: [Commodity#12243, Arrival_Date#12246, Modal_Price#12249]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00000-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-645-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12246), (year(cast(Arrival_Date#12246 as date)) >= 2024)]
#
# (2) PhotonProject
# Input [3]: [Commodity#12243, Arrival_Date#12246, Modal_Price#12249]
# Arguments: [Commodity#12243, year(cast(Arrival_Date#12246 as date)) AS Year#17607, Modal_Price#12249 AS Modal_Price#12749]
#
# (3) PhotonScan parquet
# Output [3]: [Commodity#12261, Arrival_Date#12264, Modal_Price#12267]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00001-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-649-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12264), (year(cast(Arrival_Date#12264 as date)) >= 2024)]
#
# (4) PhotonProject
# Input [3]: [Commodity#12261, Arrival_Date#12264, Modal_Price#12267]
# Arguments: [Commodity#12261, year(cast(Arrival_Date#12264 as date)) AS Year#20085, Modal_Price#12267]
#
# (5) PhotonScan parquet
# Output [3]: [Commodity#12279, Arrival_Date#12282, Modal_Price#12285]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00002-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-650-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12282), (year(cast(Arrival_Date#12282 as date)) >= 2024)]
#
# (6) PhotonProject
# Input [3]: [Commodity#12279, Arrival_Date#12282, Modal_Price#12285]
# Arguments: [Commodity#12279, year(cast(Arrival_Date#12282 as date)) AS Year#20086, Modal_Price#12285]
#
# (7) PhotonScan parquet
# Output [3]: [Commodity#12297, Arrival_Date#12300, Modal_Price#12303]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00003-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-651-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12300), (year(cast(Arrival_Date#12300 as date)) >= 2024)]
#
# (8) PhotonProject
# Input [3]: [Commodity#12297, Arrival_Date#12300, Modal_Price#12303]
# Arguments: [Commodity#12297, year(cast(Arrival_Date#12300 as date)) AS Year#20087, Modal_Price#12303]
#
# (9) PhotonScan parquet
# Output [3]: [Commodity#12315, Arrival_Date#12318, Modal_Price#12321]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00004-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-652-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12318), (year(cast(Arrival_Date#12318 as date)) >= 2024)]
#
# (10) PhotonProject
# Input [3]: [Commodity#12315, Arrival_Date#12318, Modal_Price#12321]
# Arguments: [Commodity#12315, year(cast(Arrival_Date#12318 as date)) AS Year#20088, Modal_Price#12321]
#
# (11) PhotonScan parquet
# Output [3]: [Commodity#12333, Arrival_Date#12336, Modal_Price#12339]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00005-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-653-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12336), (year(cast(Arrival_Date#12336 as date)) >= 2024)]
#
# (12) PhotonProject
# Input [3]: [Commodity#12333, Arrival_Date#12336, Modal_Price#12339]
# Arguments: [Commodity#12333, year(cast(Arrival_Date#12336 as date)) AS Year#20089, Modal_Price#12339]
#
# (13) PhotonScan parquet
# Output [3]: [Commodity#12351, Arrival_Date#12354, Modal_Price#12357]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00006-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-654-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12354), (year(cast(Arrival_Date#12354 as date)) >= 2024)]
#
# (14) PhotonProject
# Input [3]: [Commodity#12351, Arrival_Date#12354, Modal_Price#12357]
# Arguments: [Commodity#12351, year(cast(Arrival_Date#12354 as date)) AS Year#20090, Modal_Price#12357]
#
# (15) PhotonScan parquet
# Output [3]: [Commodity#12369, Arrival_Date#12372, Modal_Price#12375]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00007-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-646-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12372), (year(cast(Arrival_Date#12372 as date)) >= 2024)]
#
# (16) PhotonProject
# Input [3]: [Commodity#12369, Arrival_Date#12372, Modal_Price#12375]
# Arguments: [Commodity#12369, year(cast(Arrival_Date#12372 as date)) AS Year#20091, Modal_Price#12375]
#
# (17) PhotonScan parquet
# Output [3]: [Commodity#12387, Arrival_Date#12390, Modal_Price#12393]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00008-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-655-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12390), (year(cast(Arrival_Date#12390 as date)) >= 2024)]
#
# (18) PhotonProject
# Input [3]: [Commodity#12387, Arrival_Date#12390, Modal_Price#12393]
# Arguments: [Commodity#12387, year(cast(Arrival_Date#12390 as date)) AS Year#20092, Modal_Price#12393]
#
# (19) PhotonScan parquet
# Output [3]: [Commodity#12405, Arrival_Date#12408, Modal_Price#12411]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00009-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-656-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12408), (year(cast(Arrival_Date#12408 as date)) >= 2024)]
#
# (20) PhotonProject
# Input [3]: [Commodity#12405, Arrival_Date#12408, Modal_Price#12411]
# Arguments: [Commodity#12405, year(cast(Arrival_Date#12408 as date)) AS Year#20093, Modal_Price#12411]
#
# (21) PhotonScan parquet
# Output [3]: [Commodity#12423, Arrival_Date#12426, Modal_Price#12429]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00010-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-657-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12426), (year(cast(Arrival_Date#12426 as date)) >= 2024)]
#
# (22) PhotonProject
# Input [3]: [Commodity#12423, Arrival_Date#12426, Modal_Price#12429]
# Arguments: [Commodity#12423, year(cast(Arrival_Date#12426 as date)) AS Year#20094, Modal_Price#12429]
#
# (23) PhotonScan parquet
# Output [3]: [Commodity#12441, Arrival_Date#12444, Modal_Price#12447]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00011-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-658-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12444), (year(cast(Arrival_Date#12444 as date)) >= 2024)]
#
# (24) PhotonProject
# Input [3]: [Commodity#12441, Arrival_Date#12444, Modal_Price#12447]
# Arguments: [Commodity#12441, year(cast(Arrival_Date#12444 as date)) AS Year#20095, Modal_Price#12447]
#
# (25) PhotonScan parquet
# Output [3]: [Commodity#12459, Arrival_Date#12462, Modal_Price#12465]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00012-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-659-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12462), (year(cast(Arrival_Date#12462 as date)) >= 2024)]
#
# (26) PhotonProject
# Input [3]: [Commodity#12459, Arrival_Date#12462, Modal_Price#12465]
# Arguments: [Commodity#12459, year(cast(Arrival_Date#12462 as date)) AS Year#20096, Modal_Price#12465]
#
# (27) PhotonScan parquet
# Output [3]: [Commodity#12477, Arrival_Date#12480, Modal_Price#12483]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00013-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-660-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12480), (year(cast(Arrival_Date#12480 as date)) >= 2024)]
#
# (28) PhotonProject
# Input [3]: [Commodity#12477, Arrival_Date#12480, Modal_Price#12483]
# Arguments: [Commodity#12477, year(cast(Arrival_Date#12480 as date)) AS Year#20097, Modal_Price#12483]
#
# (29) PhotonScan parquet
# Output [3]: [Commodity#12495, Arrival_Date#12498, Modal_Price#12501]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00014-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-647-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12498), (year(cast(Arrival_Date#12498 as date)) >= 2024)]
#
# (30) PhotonProject
# Input [3]: [Commodity#12495, Arrival_Date#12498, Modal_Price#12501]
# Arguments: [Commodity#12495, year(cast(Arrival_Date#12498 as date)) AS Year#20098, Modal_Price#12501]
#
# (31) PhotonScan parquet
# Output [3]: [Commodity#12513, Arrival_Date#12516, Modal_Price#12519]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00015-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-661-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12516), (year(cast(Arrival_Date#12516 as date)) >= 2024)]
#
# (32) PhotonProject
# Input [3]: [Commodity#12513, Arrival_Date#12516, Modal_Price#12519]
# Arguments: [Commodity#12513, year(cast(Arrival_Date#12516 as date)) AS Year#20099, Modal_Price#12519]
#
# (33) PhotonScan parquet
# Output [3]: [Commodity#12531, Arrival_Date#12534, Modal_Price#12537]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00016-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-662-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12534), (year(cast(Arrival_Date#12534 as date)) >= 2024)]
#
# (34) PhotonProject
# Input [3]: [Commodity#12531, Arrival_Date#12534, Modal_Price#12537]
# Arguments: [Commodity#12531, year(cast(Arrival_Date#12534 as date)) AS Year#20100, Modal_Price#12537]
#
# (35) PhotonScan parquet
# Output [3]: [Commodity#12549, Arrival_Date#12552, Modal_Price#12555]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00017-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-648-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12552), (year(cast(Arrival_Date#12552 as date)) >= 2024)]
#
# (36) PhotonProject
# Input [3]: [Commodity#12549, Arrival_Date#12552, Modal_Price#12555]
# Arguments: [Commodity#12549, year(cast(Arrival_Date#12552 as date)) AS Year#20101, Modal_Price#12555]
#
# (37) PhotonScan parquet
# Output [3]: [Commodity#12567, Arrival_Date#12570, Modal_Price#12573]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00018-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-663-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12570), (year(cast(Arrival_Date#12570 as date)) >= 2024)]
#
# (38) PhotonProject
# Input [3]: [Commodity#12567, Arrival_Date#12570, Modal_Price#12573]
# Arguments: [Commodity#12567, year(cast(Arrival_Date#12570 as date)) AS Year#20102, Modal_Price#12573]
#
# (39) PhotonScan parquet
# Output [3]: [Commodity#12585, Arrival_Date#12588, Modal_Price#12591]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00019-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-664-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12588), (year(cast(Arrival_Date#12588 as date)) >= 2024)]
#
# (40) PhotonProject
# Input [3]: [Commodity#12585, Arrival_Date#12588, Modal_Price#12591]
# Arguments: [Commodity#12585, year(cast(Arrival_Date#12588 as date)) AS Year#20103, Modal_Price#12591]
#
# (41) PhotonScan parquet
# Output [3]: [Commodity#12603, Arrival_Date#12606, Modal_Price#12609]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00020-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-665-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12606), (year(cast(Arrival_Date#12606 as date)) >= 2024)]
#
# (42) PhotonProject
# Input [3]: [Commodity#12603, Arrival_Date#12606, Modal_Price#12609]
# Arguments: [Commodity#12603, year(cast(Arrival_Date#12606 as date)) AS Year#20104, Modal_Price#12609]
#
# (43) PhotonScan parquet
# Output [3]: [Commodity#12621, Arrival_Date#12624, Modal_Price#12627]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00021-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-666-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12624), (year(cast(Arrival_Date#12624 as date)) >= 2024)]
#
# (44) PhotonProject
# Input [3]: [Commodity#12621, Arrival_Date#12624, Modal_Price#12627]
# Arguments: [Commodity#12621, year(cast(Arrival_Date#12624 as date)) AS Year#20105, Modal_Price#12627]
#
# (45) PhotonScan parquet
# Output [3]: [Commodity#12639, Arrival_Date#12642, Modal_Price#12645]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00022-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-667-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12642), (year(cast(Arrival_Date#12642 as date)) >= 2024)]
#
# (46) PhotonProject
# Input [3]: [Commodity#12639, Arrival_Date#12642, Modal_Price#12645]
# Arguments: [Commodity#12639, year(cast(Arrival_Date#12642 as date)) AS Year#20106, Modal_Price#12645]
#
# (47) PhotonScan parquet
# Output [3]: [Commodity#12657, Arrival_Date#12660, Modal_Price#12663]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00023-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-668-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12660), (year(cast(Arrival_Date#12660 as date)) >= 2024)]
#
# (48) PhotonProject
# Input [3]: [Commodity#12657, Arrival_Date#12660, Modal_Price#12663]
# Arguments: [Commodity#12657, year(cast(Arrival_Date#12660 as date)) AS Year#20107, Modal_Price#12663]
#
# (49) PhotonScan parquet
# Output [3]: [Commodity#12675, Arrival_Date#12678, Modal_Price#12681]
# Location: InMemoryFileIndex [dbfs:/Volumes/workspace/default/pyspark/part-00024-tid-7275890549864832928-e5dd427b-4466-49fb-8a41-bd4a6b6f9b3a-669-1.c000.snappy.parquet]
# ReadSchema: struct<Commodity:string,Arrival_Date:string,Modal_Price:double>
# RequiredDataFilters: [isnotnull(Arrival_Date#12678), (year(cast(Arrival_Date#12678 as date)) >= 2024)]
#
# (50) PhotonProject
# Input [3]: [Commodity#12675, Arrival_Date#12678, Modal_Price#12681]
# Arguments: [Commodity#12675, year(cast(Arrival_Date#12678 as date)) AS Year#20108, Modal_Price#12681]
#
# (51) PhotonUnion
# Arguments: Generic
#
# (52) PhotonShuffleExchangeSink
# Input [3]: [Commodity#12243, Year#17607, Modal_Price#12749]
# Arguments: hashpartitioning(Year#17607, 1024)
#
# (53) PhotonShuffleMapStage
# Input [3]: [Commodity#12243, Year#17607, Modal_Price#12749]
# Arguments: REPARTITION_BY_COL, [id=#38571]
#
# (54) PhotonShuffleExchangeSource
# Input [3]: [Commodity#12243, Year#17607, Modal_Price#12749]
#
# (55) PhotonGroupingAgg
# Input [3]: [Commodity#12243, Year#17607, Modal_Price#12749]
# Arguments: [Commodity#12243, Year#17607], [avg(Modal_Price#12749)], [avg(Modal_Price)#20084], [Commodity#12243, Year#17607, avg(Modal_Price)#20084 AS AvgPrice#17608], true
#
# (56) PhotonResultStage
# Input [3]: [Commodity#12243, Year#17607, AvgPrice#17608]
#
# (57) ColumnarToRow
# Input [3]: [Commodity#12243, Year#17607, AvgPrice#17608]
#
# (58) AdaptiveSparkPlan
# Output [3]: [Commodity#12243, Year#17607, AvgPrice#17608]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# OPTIMIZED COUNT:

# %% [markdown]
# ## Explanation
#
# In the unoptimised version of the query, Spark ends up doing a lot of unnecessary work. The code forces Spark to scan every parquet file, shuffle a huge amount of data, and only later apply the filter for Year >= 2024. Because the filter comes so late, Spark first processes millions of rows and then throws most of them away. The plan also shows a repartition(2000), which creates a massive shuffle across the cluster for no good reason. This leads to lots of expensive stages like PhotonShuffleExchange and PhotonShuffleMapStage, which slow everything down.
#
# Even though the code is not written well, Spark still tries to be smart. It automatically pushes the year filter down into the file scan step, which means it skips reading row groups that don’t match. Spark also does “column pruning”, meaning it only loads the columns that are actually used in the query. These built-in optimisations help, but they can’t fix the huge shuffle caused by the bad repartition and late filtering.
#
# The optimised query is much cleaner and way faster. It applies the filter before any heavy operations, so Spark only processes the data it needs. It also selects only the required columns early on, reducing unnecessary I/O. Instead of randomly doing repartition(2000), the optimised query uses repartition("Year"), which groups data by the same year and avoids a giant shuffle. Because of these changes, the physical plan becomes much smaller, with fewer shuffle stages and no extra sorting. Overall, the optimised version runs faster, uses fewer resources, and takes advantage of Spark’s built-in optimisations properly.

# %% [markdown]
# # 3. Actions vs Transformations

# %%
df = spark.read.parquet("/Volumes/workspace/default/pyspark_clean")
print("Dataset loaded.")
# Out:
# Dataset loaded.

# %%
from pyspark.sql import functions as F

# Transformation 1: filter rows after 2020
df_filtered = df.filter(F.col("Arrival_Date") >= "2020-01-01")

# Transformation 2: add Price Spread column
df_with_spread = df_filtered.withColumn(
    "Price_Spread", F.col("Max_Price") - F.col("Min_Price")
)

# Transformation 3: extract year from date
df_final = df_with_spread.withColumn("Year", F.year("Arrival_Date"))

print("Transformations defined. No Spark job has run yet.")
# Out:
# Transformations defined. No Spark job has run yet.

# %%
print("Triggering first action with show():")
display(df_final.show(5))
# Out:
# Triggering first action with show():
# +--------------+------------+--------------------+--------------+-------------+-----+------------+---------+---------+-----------+--------------+------------+----+
# |         State|    District|              Market|     Commodity|      Variety|Grade|Arrival_Date|Min_Price|Max_Price|Modal_Price|Commodity_Code|Price_Spread|Year|
# +--------------+------------+--------------------+--------------+-------------+-----+------------+---------+---------+-----------+--------------+------------+----+
# |Andhra Pradesh|     Chittor|            Chittoor| Gur (Jaggery)|         NO 2|  FAQ|  2025-01-01|   3200.0|   3500.0|     3500.0|            74|       300.0|2025|
# |    Tamil Nadu|The Nilgiris|Gudalur (Uzhavar ...|        Garlic|      Average|Local|  2025-01-01|  28000.0|  30000.0|    30000.0|            25|      2000.0|2025|
# |    Tamil Nadu|The Nilgiris|Gudalur (Uzhavar ...|Ginger (Green)| Green Ginger|Local|  2025-01-01|   7000.0|   8000.0|     8000.0|           103|      1000.0|2025|
# |    Tamil Nadu|The Nilgiris|Gudalur (Uzhavar ...|  Green Chilli| Green Chilly|Local|  2025-01-01|   4500.0|   5000.0|     5000.0|            87|       500.0|2025|
# |    Tamil Nadu|The Nilgiris|Gudalur (Uzhavar ...| Mint (Pudina)|Mint (Pudina)|Local|  2025-01-01|   4500.0|   5000.0|     5000.0|           360|       500.0|2025|
# +--------------+------------+--------------------+--------------+-------------+-----+------------+---------+---------+-----------+--------------+------------+----+
# only showing top 5 rows

# %%
print("Triggering another action (count()):")
df_final.count()
# Out:
# Triggering another action (count()):
# 27466611

# %% [markdown]
# # ML-LIB

# %%
df = spark.read.parquet("/Volumes/workspace/default/pyspark_clean")

# %%
from pyspark.sql import functions as F
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression

# Feature engineering (if not already done)
df_ml = (
    df
    .withColumn("Price_Spread", F.col("Max_Price") - F.col("Min_Price"))
    .select(
        "Modal_Price",
        "Min_Price",
        "Max_Price",
        "Price_Spread",
        "Commodity_Code"
    )
    .dropna()
)

# %%
assembler = VectorAssembler(
    inputCols=["Min_Price", "Max_Price", "Price_Spread", "Commodity_Code"],
    outputCol="features"
)

df_features = assembler.transform(df_ml)

# %%
train_df, test_df = df_features.randomSplit([0.8, 0.2], seed=42)

# %%
lr = LinearRegression(
    featuresCol="features",
    labelCol="Modal_Price"
)

lr_model = lr.fit(train_df)

# %%
predictions = lr_model.transform(test_df)
predictions.select("Modal_Price", "prediction").show(10)
# Out:
# +-----------+-----------------+
# |Modal_Price|       prediction|
# +-----------+-----------------+
# |        1.0|368.5935170255327|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# |        1.0|419.2263044773363|
# +-----------+-----------------+
# only showing top 10 rows

# %%
print("RMSE:", lr_model.summary.rootMeanSquaredError)
print("R2:", lr_model.summary.r2)
# Out:
# RMSE: 1567.4901111068248
# R2: 0.9999142741087812
